# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

import os
import sys

# librosa is a Python library for analyzing audio and music. It can be used to extract the data from the audio files we will see it later.
import librosa
import librosa.display
import seaborn as sns
import matplotlib.pyplot as plt
import pickle 

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# to play the audio files
from IPython.display import Audio

from tensorflow import keras
from keras.callbacks import ReduceLROnPlateau
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization
from keras.utils import np_utils, to_categorical
from keras.callbacks import ModelCheckpoint

import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
features_csv = r"C:/Users/gusta/Documents/Data Science Bootcamp/Data Science/Final Project/Data/features.csv"

Features = pd.read_csv(features_csv)

# %% [markdown]
# ## Preprocesing the Data for Modelling

# %%
X = Features.iloc[: ,:-1].values
Y = Features['labels'].values

# %%
# As this is a multiclass classification problem onehotencoding our Y.
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
# splitting data
x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=0, shuffle=True)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((27364, 162), (27364, 8), (9122, 162), (9122, 8))

# %%
# scaling our data with sklearn's Standard scaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((27364, 162), (27364, 8), (9122, 162), (9122, 8))

# %%
# making our data compatible to model.
x_train = np.expand_dims(x_train, axis=2)
x_test = np.expand_dims(x_test, axis=2)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((27364, 162, 1), (27364, 8), (9122, 162, 1), (9122, 8))

# %% [markdown]
# ## Modelling

# %%
model=Sequential()
model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(x_train.shape[1], 1)))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Conv1D(128, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))
model.add(Dropout(0.2))

model.add(Conv1D(64, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Flatten())
model.add(Dense(units=32, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(units=8, activation='softmax'))
model.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 162, 256)          1536
#
#  max_pooling1d (MaxPooling1D  (None, 81, 256)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 81, 256)           327936
#
#  max_pooling1d_1 (MaxPooling  (None, 41, 256)          0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 41, 128)           163968
#
#  max_pooling1d_2 (MaxPooling  (None, 21, 128)          0
#  1D)
#
#  dropout (Dropout)           (None, 21, 128)           0
#
#  conv1d_3 (Conv1D)           (None, 21, 64)            41024
#
#  max_pooling1d_3 (MaxPooling  (None, 11, 64)           0
#  1D)
#
#  flatten (Flatten)           (None, 704)               0
#
#  dense (Dense)               (None, 32)                22560
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 8)                 264
#
# =================================================================
# Total params: 557,288
# Trainable params: 557,288
# Non-trainable params: 0
# _________________________________________________________________

# %%
rlrp = ReduceLROnPlateau(monitor='loss', factor=0.4, verbose=0, patience=2, min_lr=0.0000001)
history=model.fit(x_train, y_train, batch_size=64, epochs=50, validation_data=(x_test, y_test), callbacks=[rlrp])
# Out:
# Epoch 1/50
# 428/428 [==============================] - 105s 238ms/step - loss: 1.7020 - accuracy: 0.3118 - val_loss: 1.4582 - val_accuracy: 0.4111 - lr: 0.0010
# Epoch 2/50
# 428/428 [==============================] - 97s 226ms/step - loss: 1.4612 - accuracy: 0.4109 - val_loss: 1.3518 - val_accuracy: 0.4599 - lr: 0.0010
# Epoch 3/50
# 428/428 [==============================] - 78s 181ms/step - loss: 1.3717 - accuracy: 0.4536 - val_loss: 1.2843 - val_accuracy: 0.4941 - lr: 0.0010
# Epoch 4/50
# 428/428 [==============================] - 90s 210ms/step - loss: 1.3091 - accuracy: 0.4782 - val_loss: 1.2350 - val_accuracy: 0.4942 - lr: 0.0010
# Epoch 5/50
# 428/428 [==============================] - 98s 229ms/step - loss: 1.2606 - accuracy: 0.4961 - val_loss: 1.1979 - val_accuracy: 0.5190 - lr: 0.0010
# Epoch 6/50
# 428/428 [==============================] - 91s 212ms/step - loss: 1.2291 - accuracy: 0.5122 - val_loss: 1.1753 - val_accuracy: 0.5197 - lr: 0.0010
# Epoch 7/50
# 428/428 [==============================] - 101s 236ms/step - loss: 1.2023 - accuracy: 0.5192 - val_loss: 1.1640 - val_accuracy: 0.5361 - lr: 0.0010
# Epoch 8/50
# 428/428 [==============================] - 76s 178ms/step - loss: 1.1843 - accuracy: 0.5285 - val_loss: 1.1835 - val_accuracy: 0.5203 - lr: 0.0010
# Epoch 9/50
# 428/428 [==============================] - 87s 203ms/step - loss: 1.1530 - accuracy: 0.5446 - val_loss: 1.1442 - val_accuracy: 0.5409 - lr: 0.0010
# Epoch 10/50
# 428/428 [==============================] - 96s 225ms/step - loss: 1.1388 - accuracy: 0.5470 - val_loss: 1.1356 - val_accuracy: 0.5468 - lr: 0.0010
# Epoch 11/50
# 428/428 [==============================] - 108s 252ms/step - loss: 1.1189 - accuracy: 0.5551 - val_loss: 1.0994 - val_accuracy: 0.5607 - lr: 0.0010
# Epoch 12/50
# 428/428 [==============================] - 89s 207ms/step - loss: 1.1086 - accuracy: 0.5573 - val_loss: 1.0962 - val_accuracy: 0.5603 - lr: 0.0010
# Epoch 13/50
# 428/428 [==============================] - 88s 205ms/step - loss: 1.0908 - accuracy: 0.5654 - val_loss: 1.0833 - val_accuracy: 0.5697 - lr: 0.0010
# Epoch 14/50
# 428/428 [==============================] - 93s 216ms/step - loss: 1.0758 - accuracy: 0.5759 - val_loss: 1.1049 - val_accuracy: 0.5672 - lr: 0.0010
# Epoch 15/50
# 428/428 [==============================] - 92s 216ms/step - loss: 1.0613 - accuracy: 0.5847 - val_loss: 1.0751 - val_accuracy: 0.5744 - lr: 0.0010
# Epoch 16/50
# 428/428 [==============================] - 80s 187ms/step - loss: 1.0539 - accuracy: 0.5871 - val_loss: 1.0805 - val_accuracy: 0.5718 - lr: 0.0010
# Epoch 17/50
# 428/428 [==============================] - 75s 175ms/step - loss: 1.0383 - accuracy: 0.5906 - val_loss: 1.0710 - val_accuracy: 0.5756 - lr: 0.0010
# Epoch 18/50
# 428/428 [==============================] - 85s 199ms/step - loss: 1.0216 - accuracy: 0.5947 - val_loss: 1.0851 - val_accuracy: 0.5729 - lr: 0.0010
# Epoch 19/50
# 428/428 [==============================] - 80s 188ms/step - loss: 1.0148 - accuracy: 0.6013 - val_loss: 1.0707 - val_accuracy: 0.5749 - lr: 0.0010
# Epoch 20/50
# 428/428 [==============================] - 81s 188ms/step - loss: 0.9941 - accuracy: 0.6086 - val_loss: 1.0880 - val_accuracy: 0.5857 - lr: 0.0010
# Epoch 21/50
# 428/428 [==============================] - 84s 196ms/step - loss: 0.9963 - accuracy: 0.6123 - val_loss: 1.0823 - val_accuracy: 0.5737 - lr: 0.0010
# Epoch 22/50
# 428/428 [==============================] - 97s 226ms/step - loss: 0.9865 - accuracy: 0.6141 - val_loss: 1.0482 - val_accuracy: 0.5869 - lr: 0.0010
# Epoch 23/50
# 428/428 [==============================] - 83s 193ms/step - loss: 0.9643 - accuracy: 0.6225 - val_loss: 1.0523 - val_accuracy: 0.5959 - lr: 0.0010
# Epoch 24/50
# 428/428 [==============================] - 86s 201ms/step - loss: 0.9548 - accuracy: 0.6264 - val_loss: 1.0581 - val_accuracy: 0.5913 - lr: 0.0010
# Epoch 25/50
# 428/428 [==============================] - 71s 166ms/step - loss: 0.9534 - accuracy: 0.6218 - val_loss: 1.0549 - val_accuracy: 0.5934 - lr: 0.0010
# Epoch 26/50
# 428/428 [==============================] - 72s 168ms/step - loss: 0.9310 - accuracy: 0.6346 - val_loss: 1.0556 - val_accuracy: 0.5930 - lr: 0.0010
# Epoch 27/50
# 428/428 [==============================] - 73s 172ms/step - loss: 0.9386 - accuracy: 0.6310 - val_loss: 1.0487 - val_accuracy: 0.5907 - lr: 0.0010
# Epoch 28/50
# 428/428 [==============================] - 75s 176ms/step - loss: 0.9256 - accuracy: 0.6389 - val_loss: 1.0383 - val_accuracy: 0.6046 - lr: 0.0010
# Epoch 29/50
# 428/428 [==============================] - 75s 175ms/step - loss: 0.9077 - accuracy: 0.6457 - val_loss: 1.0442 - val_accuracy: 0.6029 - lr: 0.0010
# Epoch 30/50
# 428/428 [==============================] - 80s 186ms/step - loss: 0.9062 - accuracy: 0.6464 - val_loss: 1.0378 - val_accuracy: 0.6007 - lr: 0.0010
# Epoch 31/50
# 428/428 [==============================] - 79s 184ms/step - loss: 0.8828 - accuracy: 0.6537 - val_loss: 1.0345 - val_accuracy: 0.6024 - lr: 0.0010
# Epoch 32/50
# 428/428 [==============================] - 102s 238ms/step - loss: 0.8769 - accuracy: 0.6577 - val_loss: 1.0292 - val_accuracy: 0.5956 - lr: 0.0010
# Epoch 33/50
# 428/428 [==============================] - 94s 219ms/step - loss: 0.8748 - accuracy: 0.6568 - val_loss: 1.0804 - val_accuracy: 0.5927 - lr: 0.0010
# Epoch 34/50
# 428/428 [==============================] - 84s 195ms/step - loss: 0.8694 - accuracy: 0.6625 - val_loss: 1.0417 - val_accuracy: 0.6035 - lr: 0.0010
# Epoch 35/50
# 428/428 [==============================] - 87s 204ms/step - loss: 0.8574 - accuracy: 0.6644 - val_loss: 1.0655 - val_accuracy: 0.6007 - lr: 0.0010
# Epoch 36/50
# 428/428 [==============================] - 83s 194ms/step - loss: 0.8419 - accuracy: 0.6729 - val_loss: 1.0808 - val_accuracy: 0.5978 - lr: 0.0010
# Epoch 37/50
# 428/428 [==============================] - 93s 218ms/step - loss: 0.8455 - accuracy: 0.6706 - val_loss: 1.0800 - val_accuracy: 0.6067 - lr: 0.0010
# Epoch 38/50
# 428/428 [==============================] - 72s 169ms/step - loss: 0.8312 - accuracy: 0.6767 - val_loss: 1.0628 - val_accuracy: 0.6048 - lr: 0.0010
# Epoch 39/50
# 428/428 [==============================] - 73s 171ms/step - loss: 0.8164 - accuracy: 0.6802 - val_loss: 1.0558 - val_accuracy: 0.6094 - lr: 0.0010
# Epoch 40/50
# 428/428 [==============================] - 72s 169ms/step - loss: 0.8163 - accuracy: 0.6810 - val_loss: 1.0660 - val_accuracy: 0.6096 - lr: 0.0010
# Epoch 41/50
# 428/428 [==============================] - 87s 204ms/step - loss: 0.8061 - accuracy: 0.6852 - val_loss: 1.1077 - val_accuracy: 0.5996 - lr: 0.0010
# Epoch 42/50
# 428/428 [==============================] - 78s 183ms/step - loss: 0.8009 - accuracy: 0.6878 - val_loss: 1.0757 - val_accuracy: 0.6130 - lr: 0.0010
# Epoch 43/50
# 428/428 [==============================] - 80s 188ms/step - loss: 0.8034 - accuracy: 0.6890 - val_loss: 1.0926 - val_accuracy: 0.6028 - lr: 0.0010
# Epoch 44/50
# 428/428 [==============================] - 80s 187ms/step - loss: 0.7870 - accuracy: 0.6933 - val_loss: 1.0965 - val_accuracy: 0.6096 - lr: 0.0010
# Epoch 45/50
# 428/428 [==============================] - 75s 175ms/step - loss: 0.7810 - accuracy: 0.6968 - val_loss: 1.0639 - val_accuracy: 0.6175 - lr: 0.0010
# Epoch 46/50
# 428/428 [==============================] - 78s 183ms/step - loss: 0.7716 - accuracy: 0.7011 - val_loss: 1.1182 - val_accuracy: 0.6094 - lr: 0.0010
# Epoch 47/50
# 428/428 [==============================] - 81s 190ms/step - loss: 0.7799 - accuracy: 0.7001 - val_loss: 1.0849 - val_accuracy: 0.6044 - lr: 0.0010
# Epoch 48/50
# 428/428 [==============================] - 79s 185ms/step - loss: 0.7670 - accuracy: 0.7036 - val_loss: 1.0902 - val_accuracy: 0.6103 - lr: 0.0010
# Epoch 49/50
# 428/428 [==============================] - 82s 193ms/step - loss: 0.7839 - accuracy: 0.6970 - val_loss: 1.1034 - val_accuracy: 0.6033 - lr: 0.0010
# Epoch 50/50
# 428/428 [==============================] - 78s 182ms/step - loss: 0.7532 - accuracy: 0.7074 - val_loss: 1.0728 - val_accuracy: 0.6111 - lr: 0.0010

# %% [markdown]
# #### To save history callback

# %%
# file_path = 'C:/Users/gusta/VolafoneSER/Data/history_callback.pl'

# %%
# with open(file_path, 'wb') as file:
#     pickle.dump(history.history, file)

# %%
# with open(file_path, 'rb') as file:
#     loaded_history = pickle.load(file)

# %% [markdown]
# ## Continue Code

# %%
print("Accuracy of our model on test data : " , model.evaluate(x_test,y_test)[1]*100 , "%")

epochs = [i for i in range(50)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 286/286 [==============================] - 6s 22ms/step - loss: 1.0728 - accuracy: 0.6111
# Accuracy of our model on test data :  61.105018854141235 %

# %%
# predicting on test data.
pred_test = model.predict(x_test)
y_pred = encoder.inverse_transform(pred_test)

y_test = encoder.inverse_transform(y_test)
# Out:
# 286/286 [==============================] - 6s 20ms/step

# %%
df = pd.DataFrame(columns=['Predicted Labels', 'Actual Labels'])
df['Predicted Labels'] = y_pred.flatten()
df['Actual Labels'] = y_test.flatten()

df.sample(10)
# Out:
#      Predicted Labels Actual Labels
# 8119         surprise      surprise
# 7467          neutral       neutral
# 3580          neutral       neutral
# 3601            angry         angry
# 7589          neutral       disgust
# 7587              sad           sad
# 6763              sad           sad
# 3656          neutral       disgust
# 7014             fear          fear
# 7465            angry         angry

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (12, 10))
cm = pd.DataFrame(cm , index = [i for i in encoder.categories_] , columns = [i for i in encoder.categories_])
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.76      0.73      0.75      1438
#         calm       0.65      0.82      0.72       137
#      disgust       0.52      0.53      0.52      1468
#         fear       0.64      0.49      0.56      1424
#        happy       0.59      0.56      0.57      1462
#      neutral       0.63      0.51      0.56      1310
#          sad       0.52      0.75      0.61      1400
#     surprise       0.79      0.85      0.82       483
#
#     accuracy                           0.61      9122
#    macro avg       0.64      0.65      0.64      9122
# weighted avg       0.62      0.61      0.61      9122
